# %%
import boto3

# %%
s3 = boto3.client('s3')

# %%
bucket = s3.Bucket(name='rohiverm-boto3-test')

# %%
paginator = s3.get_paginator('list_objects_v2')

# %%
results = paginator.paginate(Bucket=bucket.name)
